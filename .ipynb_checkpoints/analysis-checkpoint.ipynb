# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

#improve resolution
# %config InlineBackend.figure_format ='retina'

# set plotting size parameter
plt.rcParams['figure.figsize'] = (17, 7)
plt.rcParams.update({'font.size': 16})

# %%
carData = pd.read_csv('cars_history.csv').iloc[:, 1:]
carData.shape
# Out:
# (446, 5)

# %%
carData.head(3)
# Out:
#                  title   mileage    price  distance      date_accessed
# 0  2015 Honda Civic EX  108597.0  13680.0      75.0  2022-09-19 16 hrs
# 1  2015 Honda Civic LX  111341.0  12450.0       NaN  2022-09-19 16 hrs
# 2  2014 Honda Civic LX   93949.0  12999.0      76.0  2022-09-19 16 hrs

# %%
carHistory = carData.groupby(['title', 'mileage', 'distance'])[
    ['date_accessed', 'price']].agg(lambda x: list(x)).reset_index()
carHistory.head(3)
# Out:
#                  title   mileage  distance  \
# 0  2012 Honda Civic EX  119807.0      96.0
# 1  2012 Honda Civic LX   34798.0      19.0
# 2  2012 Honda Civic LX   94947.0      98.0
#
#                                        date_accessed  \
# 0  [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 1  [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 2  [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
#
#                                                price
# 0  [12995.0, 12995.0, 12995.0, 12995.0, 12995.0, ...
# 1                           [8950.0, 8950.0, 9950.0]
# 2  [12900.0, 12900.0, 12900.0, 12900.0, 12900.0, ...

# %%
carHistory['priceChange'] = carHistory['price'].apply(lambda x: x[-1] - x[0])

# %%
carHistory['priceChange'].plot(kind = 'hist', bins = 20)
plt.title('Hist of Change in Price per Car', size = 15)
plt.show()

# %%
filtered = carHistory[carHistory['price'].apply(lambda x: np.ptp(x) > 50)]

fig, ax = plt.subplots()
for date, price, distance in filtered[['date_accessed', 'price', 'distance']].to_numpy():
    
    if pd.isnull(distance):
        col = 'gray'
    else:
        col = (1 - (distance/100), 0, (distance/200))
    ax.plot(date, price, alpha = 1, linewidth = 5, color = col)
plt.title('Price Over Time for Cars that Changed', size = 15)
plt.show()

# %%
filtered['priceChange'].plot(kind = 'hist', bins = 20)
plt.title('Hist of Change in Price per Car', size = 15)
plt.show()

# %%
# %%capture --no-display
filtered.plot(kind = 'scatter', x = 'priceChange', y = 'mileage', s = 15000 / filtered['distance'])
plt.title('Change in Price X mileage | larger = closer', size = 15)
plt.show()

# %%
carHistory
# Out:
#                          title   mileage  distance  \
# 0          2012 Honda Civic EX  119807.0      96.0
# 1          2012 Honda Civic LX   34798.0      19.0
# 2          2012 Honda Civic LX   94947.0      98.0
# 3          2012 Honda Civic LX   97128.0      22.0
# 4          2012 Honda Civic LX   97341.0      85.0
# ..                         ...       ...       ...
# 97     2017 Toyota Prius c One  157728.0      75.0
# 98   2017 Toyota Prius c Three  136986.0      75.0
# 99   2018 Mazda Mazda3 Touring   49593.0      79.0
# 100      2018 Toyota Prius Two  164711.0      75.0
# 101    2018 Toyota Prius c Two  171359.0      75.0
#
#                                          date_accessed  \
# 0    [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 1    [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 2    [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 3               [2022-09-24 11 hrs, 2022-09-27 01 hrs]
# 4    [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# ..                                                 ...
# 97   [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 98   [2022-09-22 11 hrs, 2022-09-24 11 hrs, 2022-09...
# 99              [2022-09-19 17 hrs, 2022-09-20 13 hrs]
# 100  [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
# 101  [2022-09-19 16 hrs, 2022-09-19 17 hrs, 2022-09...
#
#                                                  price  priceChange
# 0    [12995.0, 12995.0, 12995.0, 12995.0, 12995.0, ...          0.0
# 1                             [8950.0, 8950.0, 9950.0]       1000.0
# 2    [12900.0, 12900.0, 12900.0, 12900.0, 12900.0, ...          0.0
# 3                                   [13999.0, 13999.0]          0.0
# 4    [12995.0, 12995.0, 12995.0, 12995.0, 12995.0, ...          0.0
# ..                                                 ...          ...
# 97   [11995.0, 11995.0, 11995.0, 11995.0, 12995.0, ...       1000.0
# 98                         [13995.0, 14995.0, 14995.0]       1000.0
# 99                                  [14288.0, 14288.0]          0.0
# 100  [14995.0, 14995.0, 14995.0, 14995.0, 14995.0, ...          0.0
# 101  [12995.0, 12995.0, 12995.0, 12995.0, 12995.0, ...          0.0
#
# [102 rows x 6 columns]
